# %% [markdown]
# <a href="https://colab.research.google.com/github/Sorokina-code/NLP-course/blob/main/wiki_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://ru.wikipedia.org/wiki/Компьютерная_лингвистика'
r_wiki = requests.get(url)


headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
}

soup_wiki = BeautifulSoup(r_wiki.text, 'html.parser')

pars_wiki = soup_wiki.find_all('p') #достаем все с тегом параграфы
pars_wiki

texts_wiki= [text.get_text() for text in pars_wiki]
texts_wiki
# Out:
# ['Компью́терная лингви́стика (также: математи́ческая или вычисли́тельная лингви́стика, англ.\xa0computational linguistics)\xa0— научное направление в области математического и компьютерного моделирования интеллектуальных процессов у человека и животных при создании систем искусственного интеллекта, которое ставит своей целью использование математических моделей для описания естественных языков.\n',
#  'Компьютерная лингвистика частично пересекается с обработкой естественных языков. Однако в последней акцент делается не на абстрактные модели, а на прикладные методы описания и обработки языка для компьютерных систем.\n',
#  'Полем деятельности компьютерных лингвистов является разработка алгоритмов и прикладных программ для обработки языковой информации.\n',
# ...
